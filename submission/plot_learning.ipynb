# %%
import matplotlib.pyplot as plt
import numpy as np
import tikzplotlib
import re
from pathlib import Path

# %%
# style to sbn
plt.style.use("seaborn-v0_8")
out_dir = Path("report") / "plots"
out_dir.mkdir(exist_ok=True, parents=True)

# %%
def tikzplotlib_fix_ncols(obj):
    """
    workaround for matplotlib 3.6 renamed legend's _ncol to _ncols, which breaks tikzplotlib
    """
    if hasattr(obj, "_ncols"):
        obj._ncol = obj._ncols
    for child in obj.get_children():
        tikzplotlib_fix_ncols(child)

# %%
def plot_learning(
    log_file: str="../finetunes/hermes-3-2-3B-lora/logs/log_1741950098.txt",
    target_f: str = "loss_plot.tex",
    title: str = "Loss for Hermes 3.2.3B LoRA",
):
    loss_data = ""
    with open(log_file) as f:
        loss_data = f.readlines()
    loss_items = [re.findall(r"loss:(\d+\.\d+)", x) for x in loss_data]
    loss_items = [float(x[0]) for x in loss_items if len(x) > 0]
    loss_items
    fig = plt.figure(figsize=(8, 4))
    ax = fig.add_subplot(111)
    ax.plot(loss_items, label="loss", color="blue")
    ax.set_xlabel("Steps")
    ax.set_ylabel("Loss")
    ax.set_title(title)
    ax.legend()

    tikzplotlib_fix_ncols(fig)
    tikzplotlib.save(
        target_f,
        figure=fig,
        axis_width="0.8\\linewidth",
        axis_height="0.4\\linewidth",
        # extra_axis_parameters={
        #     "legend style": r"legend pos=outer north east",
        #     "legend columns": 1,
        #     "legend cell align": "left",
        #     "legend to name": "loss_legend",
        #     "legend entries": ["loss"],
        # },
    )
plot_learning()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 34
#      20     tikzplotlib_fix_ncols(fig)
#      21     tikzplotlib.save(
#      22         target_f,
#      23         figure=fig,
#    (...)
#      32         # },
#      33     )
# ---> 34 plot_learning()
#
# Cell In[4], line 7, in plot_learning(log_file, target_f, title)
#       1 def plot_learning(
#       2     log_file: str="../finetunes/hermes-3-2-3B-lora/logs/log_1741950098.txt",
#       3     target_f: str = "loss_plot.tex",
#       4     title: str = "Loss for Hermes 3.2.3B LoRA",
#       5 ):
#       6     loss_data = ""
# ----> 7     with open(log_file) as f:
#       8         loss_data = f.readlines()
#       9     loss_items = [re.findall(r"loss:(\d+\.\d+)", x) for x in loss_data]
#
# File ~/tugraz/cgv/hereditary/gutbrainie/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../finetunes/hermes-3-2-3B-lora/logs/log_1741950098.txt'

# %%
plot_learning(
    "../finetunes/hermes-3-2-3B-lora-long/logs/log_1747565688.txt",
    "loss_plot_long.tex",
    title="Loss for Hermes 3.2.3B LoRA with longer training",
)
